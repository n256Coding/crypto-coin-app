# %%
from data_loader import load_clustering_data, load_data


data = load_data()
# Out:
# Using the cached dataset..

# %%
data
# Out:
#             1INCH-GBP    AAVE-GBP   ADA-GBP  ALGO-GBP   AMP-GBP  ANKR-GBP  \
# Date
# 2019-03-31        NaN         NaN  0.053564       NaN       NaN  0.010153
# 2019-04-01        NaN         NaN  0.055350       NaN       NaN  0.010221
# 2019-04-02        NaN         NaN  0.065112       NaN       NaN  0.009316
# 2019-04-03        NaN         NaN  0.068857       NaN       NaN  0.008294
# 2019-04-04        NaN         NaN  0.066827       NaN       NaN  0.008756
# ...               ...         ...       ...       ...       ...       ...
# 2024-03-27   0.481307  103.684860  0.526641  0.221828  0.008452  0.044909
# 2024-03-28   0.461933   99.075859  0.513986  0.214522  0.008149  0.045017
# 2024-03-29   0.477857  101.294617  0.515634  0.216012  0.008334  0.043879
# 2024-03-30   0.473590  101.056931  0.526241  0.212649  0.008304  0.042643
# 2024-03-31   0.478161  100.127823  0.512666  0.209325  0.008200  0.048242
#
#              ANT-GBP     AR-GBP   ATOM-GBP   AVAX-GBP  ...    XCH-GBP  \
# ...

# %%
from services.main_service import transpose

data = transpose(data)

# %%
filtered = data.dropna()

# %%
filtered["Coin"].head(30).values
# Out:
# array(['ADA-GBP', 'ANKR-GBP', 'ANT-GBP', 'ATOM-GBP', 'BAT-GBP', 'BCH-GBP',
#        'BNB-GBP', 'BSV-GBP', 'BTC-GBP', 'BTG-GBP', 'CRO-GBP', 'DASH-GBP',
#        'DCR-GBP', 'DOGE-GBP', 'ENJ-GBP', 'EOS-GBP', 'ETC-GBP', 'ETH-GBP',
#        'FET-GBP', 'FIL-GBP', 'FLUX-GBP', 'FTM-GBP', 'GAS-GBP', 'GLM-GBP',
#        'GNO-GBP', 'ICX-GBP', 'IOTX-GBP', 'LINK-GBP', 'LRC-GBP', 'LTC-GBP'],
#       dtype=object)
